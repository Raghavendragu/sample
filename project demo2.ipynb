# %%
import tensorflow as tf

# Load the model
model = tf.keras.models.load_model('C:/Users/ragha/iris_detection_model.h5')

# Use the model for predictions or further processing
# ...

# %%
import cv2
import numpy as np

def preprocess_image(image_path):
    # Read the image
    image = cv2.imread(image_path)
    
    # Preprocess the image (e.g., resize, normalize, etc.)
    # Your preprocessing steps here...
    
    return preprocessed_image

# %%
from tensorflow.keras.models import load_model

# Load the pretrained iris recognition model
iris_model = load_model('C:\\Users\\ragha\\iris_detection_model.h5')

# %%
Freezing the base model

# %%
# Freeze the layers of the base model
for layer in iris_model.layers:
    layer.trainable = False

# %%
#adding new layers on top of base model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create a new model by stacking the base model and new layers
new_model = Sequential()
new_model.add(iris_model) 
num_classes = 5
new_model.add(Dense(64, activation='relu'))  # Example new layer
new_model.add(Dense(num_classes, activation='softmax'))  # Output layer with appropriate number of classes

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tensorflow import keras

# Define the target size for resizing
target_size = (128, 128)

# Define the paths to the "iris1" and "iris2" folders
iris1_folder = "C:\\Users\\ragha\\iris\\iris1"
iris2_folder = "C:\\Users\\ragha\\iris\\iris2"


# Load the image file paths from both folders
iris1_images = [os.path.join(iris1_folder, file_name) for file_name in os.listdir(iris1_folder)]
iris2_images = [os.path.join(iris2_folder, file_name) for file_name in os.listdir(iris2_folder)]

# Load the pre-trained model
model = keras.models.load_model("iris_detection_model.h5")

# Preprocess the input image
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, target_size)
    image = image / 255.0
    return image

# Initialize a dictionary to store attendance
attendance = {
    "Image1": [],
    "Image2": [],
    "Attendance": []
}

# Compare images and mark attendance
for image1_path in iris1_images:
    image1 = preprocess_image(image1_path)
    
    for image2_path in iris2_images:
        image2 = preprocess_image(image2_path)
        
        # Reshape the images to match the input shape of the model
        image1 = np.reshape(image1, (1, 128, 128, 3))
        image2 = np.reshape(image2, (1, 128, 128, 3))
        
        # Make predictions on the images
        prediction1 = model.predict(image1)
        prediction2 = model.predict(image2)
        
        # Interpret the results
        class1 = np.argmax(prediction1, axis=1)[0]
        class2 = np.argmax(prediction2, axis=1)[0]
        
        # Add attendance entry to the dictionary
        attendance["Image1"].append(image1_path)
        attendance["Image2"].append(image2_path)
        if class1 == class2:
            attendance["Attendance"].append("Present")
        else:
            attendance["Attendance"].append("Absent")

# Create a DataFrame from the attendance dictionary
attendance_df = pd.DataFrame(attendance)

# Display the attendance table
print(attendance_df)
# Out:
# ...
# 1/1 [==============================] - 0s 22ms/step
#                                      Image1  \
# 0    C:\Users\ragha\iris\iris1\Ajay (2).JPG
# 1    C:\Users\ragha\iris\iris1\Ajay (2).JPG
# 2    C:\Users\ragha\iris\iris1\Ajay (2).JPG
# 3    C:\Users\ragha\iris\iris1\Ajay (2).JPG
# 4    C:\Users\ragha\iris\iris1\Ajay (2).JPG
# ..                                      ...
# 128     C:\Users\ragha\iris\iris1\yash1.JPG
# 129     C:\Users\ragha\iris\iris1\yash1.JPG
# 130     C:\Users\ragha\iris\iris1\yash1.JPG
# 131     C:\Users\ragha\iris\iris1\yash1.JPG
# 132     C:\Users\ragha\iris\iris1\yash1.JPG
#
#                                         Image2 Attendance
# 0          C:\Users\ragha\iris\iris2\1-556.JPG    Present
# 1          C:\Users\ragha\iris\iris2\1-610.JPG    Present
# 2    C:\Users\ragha\iris\iris2\christiner1.bmp    Present
# 3        C:\Users\ragha\iris\iris2\image1.jpeg    Present
# 4        C:\Users\ragha\iris\iris2\image2.jpeg    Present
# ...

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tensorflow import keras

# Define the target size for resizing
target_size = (128, 128)

# Define the paths to the "iris1" and "iris2" folders
iris1_folder = "C:\\Users\\ragha\\iris\\iris1"
iris2_folder = "C:\\Users\\ragha\\iris\\iris2"

# Load the image file paths from both folders
iris1_images = [os.path.join(iris1_folder, file_name) for file_name in os.listdir(iris1_folder)]
iris2_images = [os.path.join(iris2_folder, file_name) for file_name in os.listdir(iris2_folder)]

# Load the pre-trained model
model = keras.models.load_model("iris_detection_model.h5")

# Preprocess the input image
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, target_size)
    image = image / 255.0
    return image

# Initialize a dictionary to store attendance
attendance = {
    "Image1": [],
    "Image2": [],
    "Attendance": []
}

# Compare images and mark attendance
for image1_path in iris1_images:
    image1 = preprocess_image(image1_path)
    
    for image2_path in iris2_images:
        image2 = preprocess_image(image2_path)
        
        # Reshape the images to match the input shape of the model
        image1 = np.reshape(image1, (1, 128, 128, 3))
        image2 = np.reshape(image2, (1, 128, 128, 3))
        
        # Make predictions on the images
        prediction1 = model.predict(image1)
        prediction2 = model.predict(image2)
        
        # Interpret the results
        class1 = np.argmax(prediction1, axis=1)[0]
        class2 = np.argmax(prediction2, axis=1)[0]
        
        # Add attendance entry to the dictionary
        attendance["Image1"].append(image1_path)
        attendance["Image2"].append(image2_path)
        if class1 == class2:
            attendance["Attendance"].append("Present")
        else:
            attendance["Attendance"].append("Absent")

# Create a DataFrame from the attendance dictionary
attendance_df = pd.DataFrame(attendance)

# Display the attendance table
print(attendance_df)
display(attendance_df)
# Out:
# ...
# 1/1 [==============================] - 0s 13ms/step
#                                                 Image1  \
# 0    C:\Users\ragha\iris\iris1\1-IMG_2016_11_21_999...
# 1    C:\Users\ragha\iris\iris1\1-IMG_2016_11_21_999...
# 2    C:\Users\ragha\iris\iris1\1-IMG_2016_11_21_999...
# 3    C:\Users\ragha\iris\iris1\1-IMG_2016_11_21_999...
# 4    C:\Users\ragha\iris\iris1\1-IMG_2016_11_21_999...
# ..                                                 ...
# 248                C:\Users\ragha\iris\iris1\yash1.JPG
# 249                C:\Users\ragha\iris\iris1\yash1.JPG
# 250                C:\Users\ragha\iris\iris1\yash1.JPG
# 251                C:\Users\ragha\iris\iris1\yash1.JPG
# 252                C:\Users\ragha\iris\iris1\yash1.JPG
#
#                                                 Image2 Attendance
# 0                  C:\Users\ragha\iris\iris2\1-556.JPG    Present
# 1                  C:\Users\ragha\iris\iris2\1-610.JPG    Present
# ...

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tensorflow import keras

# Define the target size for resizing
target_size = (128, 128)

# Define the paths to the "iris1" and "iris2" folders
iris1_folder = "C:\\Users\\ragha\\iris\\iris1"
iris2_folder = "C:\\Users\\ragha\\iris\\iris2"

# Load the image file paths from both folders
iris1_images = [os.path.join(iris1_folder, file_name) for file_name in os.listdir(iris1_folder)]
iris2_images = [os.path.join(iris2_folder, file_name) for file_name in os.listdir(iris2_folder)]

# Load the pre-trained model
model = keras.models.load_model("iris_detection_model.h5")

# Preprocess the input image
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, target_size)
    image = image / 255.0
    return image

# Initialize a list to store attendance
attendance = []

# Compare images and mark attendance
for image1_path in iris1_images:
    image1 = preprocess_image(image1_path)
    
    for image2_path in iris2_images:
        image2 = preprocess_image(image2_path)
        
        # Reshape the images to match the input shape of the model
        image1 = np.reshape(image1, (1, 128, 128, 3))
        image2 = np.reshape(image2, (1, 128, 128, 3))
        
        # Make predictions on the images
        prediction1 = model.predict(image1)
        prediction2 = model.predict(image2)
        
        # Interpret the results
        class1 = np.argmax(prediction1, axis=1)[0]
        class2 = np.argmax(prediction2, axis=1)[0]
        
        # Add attendance entry to the list
        if class1 == class2:
            attendance.append((image1_path, image2_path, "Present"))
        else:
            attendance.append((image1_path, image2_path, "Absent"))

# Create a DataFrame from the attendance list
attendance_df = pd.DataFrame(attendance, columns=["Image1", "Image2", "Attendance"])

# Display the attendance table
print(attendance_df)
display(attendance_df)
# Out:
# ...
# 1/1 [==============================] - 0s 5ms/step
#                                                 Image1  \
# 0    C:\Users\ragha\iris\iris1\1-IMG_2016_11_21_999...
# 1    C:\Users\ragha\iris\iris1\1-IMG_2016_11_21_999...
# 2    C:\Users\ragha\iris\iris1\1-IMG_2016_11_21_999...
# 3    C:\Users\ragha\iris\iris1\1-IMG_2016_11_21_999...
# 4    C:\Users\ragha\iris\iris1\1-IMG_2016_11_21_999...
# ..                                                 ...
# 248                C:\Users\ragha\iris\iris1\yash1.JPG
# 249                C:\Users\ragha\iris\iris1\yash1.JPG
# 250                C:\Users\ragha\iris\iris1\yash1.JPG
# 251                C:\Users\ragha\iris\iris1\yash1.JPG
# 252                C:\Users\ragha\iris\iris1\yash1.JPG
#
#                                                 Image2 Attendance
# 0                  C:\Users\ragha\iris\iris2\1-556.JPG    Present
# 1                  C:\Users\ragha\iris\iris2\1-610.JPG    Present
# ...

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tensorflow import keras

# Define the target size for resizing
target_size = (128, 128)

# Define the paths to the "iris1" and "iris2" folders
iris1_folder = "C:\\Users\\ragha\\iris\\iris1"
iris2_folder = "C:\\Users\\ragha\\iris\\iris2"

# Load the pre-trained model
model = keras.models.load_model("iris_detection_model.h5")

# Preprocess the input image
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, target_size)
    image = image / 255.0
    return image

# Initialize a dictionary to store attendance
attendance = {
    "Image1": [],
    "Image2": [],
    "Attendance": []
}

# Compare images and mark attendance
for image1_path in os.listdir(iris1_folder):
    image1 = preprocess_image(os.path.join(iris1_folder, image1_path))
    
    for image2_path in os.listdir(iris2_folder):
        image2 = preprocess_image(os.path.join(iris2_folder, image2_path))
        
        # Reshape the images to match the input shape of the model
        image1 = np.reshape(image1, (1, 128, 128, 3))
        image2 = np.reshape(image2, (1, 128, 128, 3))
        
        # Make predictions on the images
        prediction1 = model.predict(image1)
        prediction2 = model.predict(image2)
        
        # Calculate the similarity between the predictions
        similarity = np.linalg.norm(prediction1 - prediction2)
        
        # Add attendance entry to the dictionary
        attendance["Image1"].append(image1_path)
        attendance["Image2"].append(image2_path)
        if similarity < 0.5:  # Adjust the similarity threshold as needed
            attendance["Attendance"].append("Present")
        else:
            attendance["Attendance"].append("Absent")

# Create a DataFrame from the attendance dictionary
attendance_df = pd.DataFrame(attendance)

# Display the attendance table
print(attendance_df)
display(attendance_df)
# Out:
# ...
# 1/1 [==============================] - 0s 11ms/step
#                             Image1                         Image2 Attendance
# 0    1-IMG_2016_11_21_9999_382.JPG                      1-556.JPG    Present
# 1    1-IMG_2016_11_21_9999_382.JPG                      1-610.JPG    Present
# 2    1-IMG_2016_11_21_9999_382.JPG  1-IMG_2016_11_21_9999_382.JPG    Present
# 3    1-IMG_2016_11_21_9999_382.JPG  1-IMG_2016_11_21_9999_392.JPG    Present
# 4    1-IMG_2016_11_21_9999_382.JPG  1-IMG_2016_11_21_9999_399.JPG    Present
# ..                             ...                            ...        ...
# 248                      yash1.JPG                christiner1.bmp    Present
# 249                      yash1.JPG                    image1.jpeg    Present
# 250                      yash1.JPG                    image2.jpeg    Present
# 251                      yash1.JPG                    image5.jpeg    Present
# ...

# %%
import os

# Get the current working directory
current_dir = os.getcwd()

# List all files in the current directory
files = os.listdir(current_dir)

# Print the file names
for file in files:
    print(file)
# Out:
# .appletviewer
# .bash_history
# .cache
# .conda
# .condarc
# .continuum
# .dotnet
# .eclipse
# .gitconfig
# .ipynb_checkpoints
# .ipython
# .jupyter
# .keras
# .lemminx
# .librarymanager
# .m2
# .matplotlib
# .nbi
# .netbeans-derby
# .node_repl_history
# .p2
# .packettracer
# .spyder-py3
# .templateengine
# .vscode
# anaconda3
# ansel
# AppData
# Application Data
# attendance.xlsx
# attendance_temp.xlsx
# Cisco Packet Tracer 8.1.0
# conda
# Contacts
# Cookies
# create
# Documents
# Downloads
# eclipse
# eclipse-workspace
# eye disease model.ipynb
# Favorites
# IntelGraphicsProfiles
# iris
# iris.ipynb
# iris_detection_model.h5
# iris_detection_model.pkl
# java
# Links
# Local Settings
# Machine learning.ipynb
# Manage
# Music
# My Documents
# my-app
# NetHood
# New Project 1.ipynb
# New Project.ipynb
# NTUSER.DAT
# ntuser.dat.LOG1
# ntuser.dat.LOG2
# NTUSER.DAT{dbfb8697-f7b6-11ed-b288-d2fe67b895a7}.TM.blf
# ...

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tensorflow import keras

# Define the target size for resizing
target_size = (128, 128)

# Define the paths to the "iris1" and "iris2" folders
iris1_folder = "C:\\Users\\ragha\\iris\\iris1"
iris2_folder = "C:\\Users\\ragha\\iris\\iris2"

# Load the pre-trained model
model = keras.models.load_model("iris_detection_model.h5")

# Preprocess the input image
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, target_size)
    image = image / 255.0
    return image

# Initialize a dictionary to store attendance
attendance = {
    "Image1": [],
    "Image2": [],
    "Attendance": []
}

# Compare images and mark attendance
for image1_path in os.listdir(iris1_folder):
    image1 = preprocess_image(os.path.join(iris1_folder, image1_path))
    
    for image2_path in os.listdir(iris2_folder):
        image2 = preprocess_image(os.path.join(iris2_folder, image2_path))
        
        # Reshape the images to match the input shape of the model
        image1 = np.reshape(image1, (1, 128, 128, 3))
        image2 = np.reshape(image2, (1, 128, 128, 3))
        
        # Make predictions on the images
        prediction1 = model.predict(image1)
        prediction2 = model.predict(image2)
        
        # Calculate the similarity between the predictions
        similarity = np.linalg.norm(prediction1 - prediction2)
        
        # Add attendance entry to the dictionary
        attendance["Image1"].append(image1_path)
        attendance["Image2"].append(image2_path)
        if similarity < 10:  # Adjust the similarity threshold as needed
            attendance["Attendance"].append("Present")
        else:
            attendance["Attendance"].append("Absent")

# Create a DataFrame from the attendance dictionary
attendance_df = pd.DataFrame(attendance)

# Display the attendance table
print(attendance_df)
display(attendance_df)
# Out:
# ...
# 1/1 [==============================] - 0s 19ms/step
#                             Image1                         Image2 Attendance
# 0    1-IMG_2016_11_21_9999_382.JPG                      1-556.JPG    Present
# 1    1-IMG_2016_11_21_9999_382.JPG                      1-610.JPG    Present
# 2    1-IMG_2016_11_21_9999_382.JPG  1-IMG_2016_11_21_9999_382.JPG    Present
# 3    1-IMG_2016_11_21_9999_382.JPG  1-IMG_2016_11_21_9999_392.JPG    Present
# 4    1-IMG_2016_11_21_9999_382.JPG  1-IMG_2016_11_21_9999_399.JPG    Present
# ..                             ...                            ...        ...
# 248                      yash1.JPG                christiner1.bmp    Present
# 249                      yash1.JPG                    image1.jpeg    Present
# 250                      yash1.JPG                    image2.jpeg    Present
# 251                      yash1.JPG                    image5.jpeg    Present
# ...

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tensorflow import keras

# Define the target size for resizing
target_size = (128, 128)

# Define the paths to the "iris1" and "iris2" folders
iris1_folder = "C:\\Users\\ragha\\iris\\iris1"
iris2_folder = "C:\\Users\\ragha\\iris\\iris2"

# Load the pre-trained model
model = keras.models.load_model("iris_detection_model.h5")

# Preprocess the input image
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, target_size)
    image = image / 255.0
    return image

# Initialize a dictionary to store attendance
attendance = {
    "Image1": [],
    "Image2": [],
    "Similarity": [],  # Add similarity column
    "Attendance": []
}

# Compare images and mark attendance
for image1_path in os.listdir(iris1_folder):
    image1 = preprocess_image(os.path.join(iris1_folder, image1_path))
    
    for image2_path in os.listdir(iris2_folder):
        image2 = preprocess_image(os.path.join(iris2_folder, image2_path))
        
        # Reshape the images to match the input shape of the model
        image1 = np.reshape(image1, (1, 128, 128, 3))
        image2 = np.reshape(image2, (1, 128, 128, 3))
        
        # Make predictions on the images
        prediction1 = model.predict(image1)
        prediction2 = model.predict(image2)
        
        # Calculate the similarity between the predictions
        similarity = np.linalg.norm(prediction1 - prediction2)
        
        # Add attendance entry to the dictionary
        attendance["Image1"].append(image1_path)
        attendance["Image2"].append(image2_path)
        attendance["Similarity"].append(similarity)  # Append similarity value
        if similarity < 0.5:  # Adjust the similarity threshold as needed
            attendance["Attendance"].append("Present")
        else:
            attendance["Attendance"].append("Absent")

# Create a DataFrame from the attendance dictionary
attendance_df = pd.DataFrame(attendance)

# Display the attendance table with similarity values
print(attendance_df)
display(attendance_df)
# Out:
# ...
# 1/1 [==============================] - 0s 32ms/step
#            Image1       Image2  Similarity Attendance
# 0    Ajay (2).JPG    1-556.JPG    0.113135    Present
# 1    Ajay (2).JPG    1-610.JPG    0.062249    Present
# 2    Ajay (2).JPG  image1.jpeg    0.095630    Present
# 3    Ajay (2).JPG  image2.jpeg    0.092704    Present
# 4    Ajay (2).JPG  image5.jpeg    0.046015    Present
# ..            ...          ...         ...        ...
# 109     yash1.JPG    1-610.JPG    0.091385    Present
# 110     yash1.JPG  image1.jpeg    0.124765    Present
# 111     yash1.JPG  image2.jpeg    0.121840    Present
# 112     yash1.JPG  image5.jpeg    0.075151    Present
# 113     yash1.JPG  image6.jpeg    0.108485    Present
#
# [114 rows x 4 columns]
#            Image1       Image2  Similarity Attendance
# 0    Ajay (2).JPG    1-556.JPG    0.113135    Present
# 1    Ajay (2).JPG    1-610.JPG    0.062249    Present
# 2    Ajay (2).JPG  image1.jpeg    0.095630    Present
# ...

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tensorflow import keras
from openpyxl import load_workbook

# Define the target size for resizing
target_size = (128, 128)

# Define the paths to the "iris1" and "iris2" folders
iris1_folder = "C:\\Users\\ragha\\iris\\iris1"
iris2_folder = "C:\\Users\\ragha\\iris\\iris2"

# Load the pre-trained model
model = keras.models.load_model("iris_detection_model.h5")

# Preprocess the input image
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, target_size)
    image = image / 255.0
    return image

# Initialize a dictionary to store attendance
attendance = {
    "Image1": [],
    "Image2": [],
    "Similarity": [],
    "Attendance": []
}

# Compare images and mark attendance
for image1_path in os.listdir(iris1_folder):
    image1 = preprocess_image(os.path.join(iris1_folder, image1_path))
    
    for image2_path in os.listdir(iris2_folder):
        image2 = preprocess_image(os.path.join(iris2_folder, image2_path))
        
        # Reshape the images to match the input shape of the model
        image1 = np.reshape(image1, (1, 128, 128, 3))
        image2 = np.reshape(image2, (1, 128, 128, 3))
        
        # Make predictions on the images
        prediction1 = model.predict(image1)
        prediction2 = model.predict(image2)
        
        # Calculate the similarity between the predictions
        similarity = np.linalg.norm(prediction1 - prediction2)
        
        # Add attendance entry to the dictionary
        attendance["Image1"].append(image1_path)
        attendance["Image2"].append(image2_path)
        attendance["Similarity"].append(similarity)
        if similarity < 0.5:  # Adjust the similarity threshold as needed
            attendance["Attendance"].append("Present")
        else:
            attendance["Attendance"].append("Absent")

# Create a DataFrame from the attendance dictionary
attendance_df = pd.DataFrame(attendance)

# Save the attendance table to an Excel file
attendance_df.to_excel("attendance_temp.xlsx", index=False)

# Load the Excel file and display it
book = load_workbook("attendance_temp.xlsx")
writer = pd.ExcelWriter("attendance.xlsx", engine="openpyxl") 
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)
attendance_df.to_excel(writer, "Sheet1", index=False)
writer.save()
writer.close()
# Out:
# ...
# 1/1 [==============================] - 0s 32ms/step
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23056\3122661172.py in <module>
#      62
#      63 # Save the attendance table to an Excel file
# ---> 64 attendance_df.to_excel("attendance_temp.xlsx", index=False)
#      65
#      66 # Load the Excel file and display it
#
# ~\Downloads\anaconda\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2343             inf_rep=inf_rep,
#    2344         )
# -> 2345         formatter.write(
#    2346             excel_writer,
#    2347             sheet_name=sheet_name,
#
# ...

# %%
import os
import cv2
import numpy as np
import pandas as pd
from tensorflow import keras
from openpyxl import load_workbook

# Define the target size for resizing
target_size = (128, 128)

# Define the paths to the "iris1" and "iris2" folders
iris1_folder = "C:\\Users\\ragha\\iris\\iris2"
iris2_folder = "C:\\Users\\ragha\\iris\\iris3"

# Load the pre-trained model
model = keras.models.load_model("iris_detection_model.h5")

# Preprocess the input image
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, target_size)
    image = image / 255.0
    return image

# Initialize a dictionary to store attendance
attendance = {
    "Image1": [],
    "Image2": [],
    "Similarity": [],
    "Attendance": []
}

# Compare images and mark attendance
for image1_path in os.listdir(iris1_folder):
    image1 = preprocess_image(os.path.join(iris1_folder, image1_path))
    
    for image2_path in os.listdir(iris2_folder):
        image2 = preprocess_image(os.path.join(iris2_folder, image2_path))
        
        # Reshape the images to match the input shape of the model
        image1 = np.reshape(image1, (1, 128, 128, 3))
        image2 = np.reshape(image2, (1, 128, 128, 3))
        
        # Make predictions on the images
        prediction1 = model.predict(image1)
        prediction2 = model.predict(image2)
        
        # Calculate the similarity between the predictions
        similarity = np.linalg.norm(prediction1 - prediction2)
        
        # Add attendance entry to the dictionary
        attendance["Image1"].append(image1_path)
        attendance["Image2"].append(image2_path)
        attendance["Similarity"].append(similarity)
        if similarity<0:  # Adjust the similarity threshold as needed
            attendance["Attendance"].append("Present")
        else:
            attendance["Attendance"].append("Absent")

# Create a DataFrame from the attendance dictionary
attendance_df = pd.DataFrame(attendance)

# Save the attendance table to an Excel file
attendance_df.to_excel("attendance_temp.xlsx", index=False)

# Open the Excel file using the default application
os.startfile("attendance_temp.xlsx")
# Out:
# ...
# 1/1 [==============================] - 0s 25ms/step
